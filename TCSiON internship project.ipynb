# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from faker import Faker
import random

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\archive (1)\webmd.csv")

# %%
df.head()
# Out:
#           Age      Condition       Date                          Drug  DrugId  \
# 0  75 or over    Stuffy Nose  9/21/2014                  25dph-7.5peh  146724
# 1       25-34  Cold Symptoms  1/13/2011                  25dph-7.5peh  146724
# 2       65-74          Other  7/16/2012  warfarin (bulk) 100 % powder  144731
# 3  75 or over          Other  9/23/2010  warfarin (bulk) 100 % powder  144731
# 4       35-44          Other   1/6/2009  warfarin (bulk) 100 % powder  144731
#
#    EaseofUse  Effectiveness  \
# 0          5              5
# 1          5              5
# 2          2              3
# 3          2              2
# 4          1              1
#
#                                              Reviews  Satisfaction     Sex  \
# 0  I'm a retired physician and of all the meds I ...             5    Male
# 1  cleared me right up even with my throat hurtin...             5  Female
# 2  why did my PTINR go from a normal of 2.5 to ov...             3  Female
# ...

# %%
df.shape
# Out:
# (362806, 12)

# %%
# Generate a random name

fake = Faker()
name = fake.name()

# Generate a random race

races = ['Caucasian', 'African American', 'Asian', 'Hispanic', 'Native American']
race = random.choice(races)

# %%
# Create an instance of Faker
fake = Faker()

# Create an empty list to store the generated names and races
generated_names = []
generated_races = []

# Generate random names and races for each row in the dataset
for _ in range(len(df)):
    name = fake.name()
    race = random.choice(['Caucasian', 'African American', 'Asian', 'Hispanic', 'American'])
    generated_names.append(name)
    generated_races.append(race)

# Adding names and races as new columns to the DataFrame
df['Name'] = generated_names
df['Race'] = generated_races

# %%
df.head()
# Out:
#           Age      Condition       Date                          Drug  DrugId  \
# 0  75 or over    Stuffy Nose  9/21/2014                  25dph-7.5peh  146724
# 1       25-34  Cold Symptoms  1/13/2011                  25dph-7.5peh  146724
# 2       65-74          Other  7/16/2012  warfarin (bulk) 100 % powder  144731
# 3  75 or over          Other  9/23/2010  warfarin (bulk) 100 % powder  144731
# 4       35-44          Other   1/6/2009  warfarin (bulk) 100 % powder  144731
#
#    EaseofUse  Effectiveness  \
# 0          5              5
# 1          5              5
# 2          2              3
# 3          2              2
# 4          1              1
#
#                                              Reviews  Satisfaction     Sex  \
# 0  I'm a retired physician and of all the meds I ...             5    Male
# 1  cleared me right up even with my throat hurtin...             5  Female
# 2  why did my PTINR go from a normal of 2.5 to ov...             3  Female
# ...

# %%
# reordering and bringing the name,race and sex to beginning


df = df[['Name', 'Sex', 'Race', 'Age', 'Condition', 'Date', 'Drug', 'DrugId', 'EaseofUse', 'Effectiveness', 'Reviews', 'Satisfaction', 'Sides', 'UsefulCount']]

df.head()
# Out:
#                Name     Sex       Race         Age      Condition       Date  \
# 0     Ronald Martin    Male   Hispanic  75 or over    Stuffy Nose  9/21/2014
# 1  Benjamin Johnson  Female  Caucasian       25-34  Cold Symptoms  1/13/2011
# 2    Alexander Long  Female      Asian       65-74          Other  7/16/2012
# 3       Mark Jacobs  Female  Caucasian  75 or over          Other  9/23/2010
# 4      Rhonda Jones    Male   Hispanic       35-44          Other   1/6/2009
#
#                            Drug  DrugId  EaseofUse  Effectiveness  \
# 0                  25dph-7.5peh  146724          5              5
# 1                  25dph-7.5peh  146724          5              5
# 2  warfarin (bulk) 100 % powder  144731          2              3
# 3  warfarin (bulk) 100 % powder  144731          2              2
# 4  warfarin (bulk) 100 % powder  144731          1              1
#
#                                              Reviews  Satisfaction  \
# ...

# %%
#saving the modified dataset


df.to_csv("drugs side effect.csv", index=False)

# %% [markdown]
# # Reading the modified dataset

# %%
df = pd.read_csv("drugs side effect.csv")

# %%
df.head()
# Out:
#                Name     Sex       Race         Age      Condition       Date  \
# 0     Ronald Martin    Male   Hispanic  75 or over    Stuffy Nose  9/21/2014
# 1  Benjamin Johnson  Female  Caucasian       25-34  Cold Symptoms  1/13/2011
# 2    Alexander Long  Female      Asian       65-74          Other  7/16/2012
# 3       Mark Jacobs  Female  Caucasian  75 or over          Other  9/23/2010
# 4      Rhonda Jones    Male   Hispanic       35-44          Other   1/6/2009
#
#                            Drug  DrugId  EaseofUse  Effectiveness  \
# 0                  25dph-7.5peh  146724          5              5
# 1                  25dph-7.5peh  146724          5              5
# 2  warfarin (bulk) 100 % powder  144731          2              3
# 3  warfarin (bulk) 100 % powder  144731          2              2
# 4  warfarin (bulk) 100 % powder  144731          1              1
#
#                                              Reviews  Satisfaction  \
# ...

# %%
df.tail()
# Out:
#                       Name     Sex              Race    Age     Condition  \
# 362801       Michael Grant  Female          American  55-64  Stop Smoking
# 362802   Cassandra Pacheco                     Asian                Other
# 362803  Alexander Williams  Female  African American  25-34  Stop Smoking
# 362804       Joseph Morris    Male  African American  55-64  Stop Smoking
# 362805         Barry Moore  Female  African American  45-54  Stop Smoking
#
#               Date     Drug  DrugId  EaseofUse  Effectiveness  \
# 362801  11/14/2008  chantix  144470          5              5
# 362802  11/14/2008  chantix  144470          2              3
# 362803  11/13/2008  chantix  144470          2              4
# 362804  11/13/2008  chantix  144470          5              5
# 362805  11/12/2008  chantix  144470          4              5
#
#                                                   Reviews  Satisfaction  \
# ...

# %%
df.shape
# Out:
# (362806, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362806 entries, 0 to 362805
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Name           362806 non-null  object
#  1   Sex            362806 non-null  object
#  2   Race           362806 non-null  object
#  3   Age            362806 non-null  object
#  4   Condition      362806 non-null  object
#  5   Date           362806 non-null  object
#  6   Drug           362806 non-null  object
#  7   DrugId         362806 non-null  int64
#  8   EaseofUse      362806 non-null  int64
#  9   Effectiveness  362806 non-null  int64
#  10  Reviews        362769 non-null  object
#  11  Satisfaction   362806 non-null  int64
#  12  Sides          362806 non-null  object
#  13  UsefulCount    362806 non-null  int64
# dtypes: int64(5), object(9)
# memory usage: 38.8+ MB

# %%
df.isna().sum()
# Out:
# Name              0
# Sex               0
# Race              0
# Age               0
# Condition         0
# Date              0
# Drug              0
# DrugId            0
# EaseofUse         0
# Effectiveness     0
# Reviews          37
# Satisfaction      0
# Sides             0
# UsefulCount       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe(include='object').T
# Out:
#             count  unique            top    freq
# Name       362806  180784  Michael Smith     175
# Sex        362806       3         Female  238226
# Race       362806       5       American   72901
# Age        362806      12          45-54   80043
# Condition  362806    1806          Other   49765
# Date       362806    4524     10/29/2007     404
# Drug       362806    7093       cymbalta    4648
# Reviews    362769  250167                  41824
# Sides      362806    1651                  17460

# %%
df.describe().T
# Out:
#                   count          mean           std  min     25%     50%  \
# DrugId         362806.0  36879.370774  52624.412971  1.0  4896.0  9548.0
# EaseofUse      362806.0      4.019829      1.317711  1.0     3.0     5.0
# Effectiveness  362806.0      3.532061      1.455961  1.0     3.0     4.0
# Satisfaction   362806.0      3.135408      1.611106  1.0     1.0     3.0
# UsefulCount    362806.0      6.744916      9.324240  0.0     1.0     4.0
#
#                    75%       max
# DrugId         63522.0  178546.0
# EaseofUse          5.0      10.0
# Effectiveness      5.0      10.0
# Satisfaction       5.0      10.0
# UsefulCount        9.0     255.0

# %%
df.columns
# Out:
# Index(['Name', 'Sex', 'Race', 'Age', 'Condition', 'Date', 'Drug', 'DrugId',
#        'EaseofUse', 'Effectiveness', 'Reviews', 'Satisfaction', 'Sides',
#        'UsefulCount'],
#       dtype='object')

# %%
for i in df.columns:
    print(i,':',df[i].nunique(),'\n')
# Out:
# Name : 180784
#
# Sex : 3
#
# Race : 5
#
# Age : 12
#
# Condition : 1806
#
# Date : 4524
#
# Drug : 7093
#
# DrugId : 6572
#
# EaseofUse : 7
#
# Effectiveness : 7
#
# Reviews : 250167
#
# Satisfaction : 7
#
# Sides : 1651
#
# UsefulCount : 148

# %%
df['Name'].value_counts()
# Out:
# Michael Smith        175
# Michael Johnson      132
# Michael Jones        117
# Michael Williams     115
# James Smith          111
#                     ...
# Sharon Simpson         1
# Frank Terry            1
# Jesse Black            1
# Kelly Sexton           1
# Cassandra Pacheco      1
# Name: Name, Length: 180784, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# Female    238226
# Male       98043
#            26537
# Name: Sex, dtype: int64

# %%
df['Race'].value_counts()
# Out:
# American            72901
# African American    72652
# Caucasian           72620
# Hispanic            72414
# Asian               72219
# Name: Race, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# 45-54         80043
# 55-64         75136
# 35-44         55011
# 25-34         49718
# 65-74         41216
# 19-24         24230
# 75 or over    15226
#               12202
# 13-18          7045
# 7-12           1644
# 3-6             838
# 0-2             497
# Name: Age, dtype: int64

# %%
df['Condition'].value_counts()
# Out:
# Other                                                  49765
# Pain                                                   25232
# High Blood Pressure                                    23275
# Depression                                             14509
# Birth Control                                          12253
#                                                        ...
# Diagnostic Test for Myasthenia Gravis                      1
# Myelodysplastic Syndrome with 5q Deletion Gene Type        1
# Hunter Syndrome                                            1
# Increased Uric Acid due to Cancer Chemotherapy             1
# Adverse Effect of Benzodiazepine-Based Tranquilizer        1
# Name: Condition, Length: 1806, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# 10/29/2007    404
# 10/30/2007    316
# 10/28/2007    315
# 3/15/2010     308
# 3/16/2010     295
#              ...
# 10/19/2019      2
# 10/27/2019      1
# 10/20/2019      1
# 6/28/2019       1
# 6/22/2019       1
# Name: Date, Length: 4524, dtype: int64

# %%
df['Drug'].value_counts()
# Out:
# cymbalta                               4648
# lisinopril                             4269
# lisinopril solution                    4269
# lexapro                                4134
# hydrocodone-acetaminophen              3944
#                                        ...
# sorbsan bandage                           1
# sorbsan topical wound dressing 3" x       1
# q-pap extra strength                      1
# symax                                     1
# vanadium granules                         1
# Name: Drug, Length: 7093, dtype: int64

# %%
df['DrugId'].value_counts()
# Out:
# 6873      8538
# 1025      7868
# 6007      7728
# 4398      5864
# 14208     5451
#           ...
# 4118         1
# 165948       1
# 54215        1
# 154021       1
# 149247       1
# Name: DrugId, Length: 6572, dtype: int64

# %%
df['EaseofUse'].value_counts()
# Out:
# 5     192650
# 4      74732
# 3      41303
# 1      35927
# 2      18191
# 6          2
# 10         1
# Name: EaseofUse, dtype: int64

# %%
df['Effectiveness'].value_counts()
# Out:
# 5     130388
# 4      81821
# 3      60406
# 1      59387
# 2      30801
# 6          2
# 10         1
# Name: Effectiveness, dtype: int64

# %%
df['Reviews'].value_counts()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            41824
# ...

# %%
df['Satisfaction'].value_counts()
# Out:
# 5     111550
# 1     100901
# 4      63158
# 3      51852
# 2      35342
# 6          2
# 10         1
# Name: Satisfaction, dtype: int64

# %%
df['Sides'].value_counts()
# Out:
#                                                                                                                                                        17460
# Nausea ,  vomiting ,  constipation ,  lightheadedness ,  dizziness , or drowsiness may occur.                                                          15563
# Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, swelling of the  ankles /feet (fluid retention), or  weight  change may occur.       12116
# Dizziness ,  lightheadedness , tiredness, or  headache  may occur as your body adjusts to the  medication . Dry  cough  may also occur.                 9162
# Drowsiness,  dizziness , loss of coordination, tiredness, blurred/ double vision , unusual  eye  movements, or shaking (tremor) may occur.              7790
#                                                                                                                                                        ...
# ...

# %%
# Distribution of Age
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Age')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Sex', palette='Set3')
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Count of Patients by Race

plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Race')
plt.title('Count of Patients by Race')
plt.xlabel('Race')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Top 20 Drugs
top_drugs = df['Drug'].value_counts().head(20)

plt.figure(figsize=(10, 8))
sns.barplot(x=top_drugs.values, y=top_drugs.index, palette='Set3')
plt.title("Top 20 Drugs")
plt.xlabel("Count")
plt.ylabel("Drug")
plt.xticks(fontsize=10)  
plt.yticks(fontsize=10) 
plt.show()

# %%
top_conditions = df['Condition'].value_counts().head(20)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_conditions.index, y=top_conditions.values, palette='Set3')
plt.title('common conditions')
plt.xlabel('Condition')
plt.ylabel('Count')
plt.xticks(rotation=90, fontsize=10)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Effectiveness')
plt.title('Effectiveness of Drugs')
plt.xlabel('Effectiveness')
plt.ylabel('Count')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 6))
sns.pointplot(x='Age', y='Effectiveness', data=df, ax=ax, ci=None)
ax.set_title('Age vs Effectiveness')
ax.set_xlabel('Age')
ax.set_ylabel('Effectiveness')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18468\4170501485.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(x='Age', y='Effectiveness', data=df, ax=ax, ci=None)

# %% [markdown]
# # 'Lexapro' is selected in building a classification model to determine side effects.

# %%
lexapro= df.loc[(df['Drug'] =='lexapro')]
lexapro.head()
# Out:
#                  Name     Sex              Race         Age  \
# 28803  Robert Jackson  Female  African American       35-44
# 28809  Shelley Fisher  Female             Asian
# 28817    Jordan Baker    Male  African American       55-64
# 28826     Regina Leon  Female          American       65-74
# 28834   Lisa Mcmillan  Female             Asian  75 or over
#
#                                     Condition        Date     Drug  DrugId  \
# 28803  Anxiousness associated with Depression    2/6/2020  lexapro   63990
# 28809                  "Change of Life" Signs   1/23/2020  lexapro   63990
# 28817                              Depression   1/23/2020  lexapro   63990
# 28826                              Depression   1/21/2020  lexapro   63990
# 28834  Anxiousness associated with Depression  12/27/2019  lexapro   63990
#
#        EaseofUse  Effectiveness  \
# 28803          1              1
# 28809          3              2
# 28817          5              3
# ...

# %%
lexapro.shape
# Out:
# (4134, 14)

# %%
lexapro['Condition'].value_counts()
# Out:
# Depression                                1920
# Repeated Episodes of Anxiety               921
# Panic Disorder                             311
# Other                                      244
# Major Depressive Disorder                  194
# Bipolar Depression                         192
# "Change of Life" Signs                     146
# Posttraumatic Stress Syndrome               89
# Obsessive Compulsive Disorder               69
# Anxiousness associated with Depression      47
#                                              1
# Name: Condition, dtype: int64

# %%
df_new = lexapro.copy()

# %%
df_copy = df.copy

# %% [markdown]
# # Preprocessing

# %%
# Treating blank spaces


for i in df_new:
    df_new[i] = np.where(df_new[i] == " ", np.nan, df_new[i])

# %%
df_new.head()
# Out:
#                  Name     Sex              Race         Age  \
# 28803  Robert Jackson  Female  African American       35-44
# 28809  Shelley Fisher  Female             Asian         NaN
# 28817    Jordan Baker    Male  African American       55-64
# 28826     Regina Leon  Female          American       65-74
# 28834   Lisa Mcmillan  Female             Asian  75 or over
#
#                                     Condition        Date     Drug   DrugId  \
# 28803  Anxiousness associated with Depression    2/6/2020  lexapro  63990.0
# 28809                  "Change of Life" Signs   1/23/2020  lexapro  63990.0
# 28817                              Depression   1/23/2020  lexapro  63990.0
# 28826                              Depression   1/21/2020  lexapro  63990.0
# 28834  Anxiousness associated with Depression  12/27/2019  lexapro  63990.0
#
#        EaseofUse  Effectiveness  \
# 28803        1.0            1.0
# 28809        3.0            2.0
# 28817        5.0            3.0
# ...

# %% [markdown]
# # Checking for null values

# %%
df_new.isnull().sum()
# Out:
# Name               0
# Sex              222
# Race               0
# Age              175
# Condition          1
# Date               0
# Drug               0
# DrugId             0
# EaseofUse          0
# Effectiveness      0
# Reviews          568
# Satisfaction       0
# Sides              0
# UsefulCount        0
# dtype: int64

# %% [markdown]
# # Bar plot showing the null value count of each feature

# %%
missing = (df_new.isnull().sum()).sort_values(ascending=False)
missing.plot(kind="bar", figsize=(12, 6), fontsize=10, color='violet')
plt.xlabel("Columns", fontsize=20)
plt.ylabel("", fontsize=20)
plt.title("Total Missing Values", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Total Missing Values')

# %%
# Removing rows with null data

df_new = df_new.dropna(axis=0)

# %%
df_new.isnull().sum()
# Out:
# Name             0
# Sex              0
# Race             0
# Age              0
# Condition        0
# Date             0
# Drug             0
# DrugId           0
# EaseofUse        0
# Effectiveness    0
# Reviews          0
# Satisfaction     0
# Sides            0
# UsefulCount      0
# dtype: int64

# %%
df_new.shape
# Out:
# (3347, 14)

# %% [markdown]
# # Text processing

# %%
# converting rows having data other than string datatype into  string.

for i in range(len(df_new)):
    if type(df_new.iloc[i]['Sides']) != str:
        df_new.at[i, 'Sides'] = str(df_new.iloc[i]['Sides'])

for i in range(len(df_new)):
    if type(df_new.iloc[i]['Reviews']) != str:
        df_new.at[i, 'Reviews'] = str(df_new.iloc[i]['Reviews'])
        
for i in range(len(df_new)):
    if type(df_new.iloc[i]['Condition']) != str:
        df_new.at[i, 'Condition'] = str(df_new.iloc[i]['Condition'])

# %%
import re
def cleaning_text(i):
    i = re.sub("[^A-Za-z" "]+"," ",i).lower()
    i = re.sub("[0-9" "]+"," ",i)
    i= re.sub("[\W+""]", " ",i)        
    w = []
    for word in i.split(" "):
        if len(word)>3:
            w.append(word)
    return (" ".join(w))

# %% [markdown]
# ### Sides

# %%
df_new['Sides'] = df_new['Sides'].apply(cleaning_text)
print(df_new['Sides'])
# Out:
# 28803    nausea mouth trouble sleeping constipation tir...
# 28817    nausea mouth trouble sleeping constipation tir...
# 28826    nausea mouth trouble sleeping constipation tir...
# 28834    nausea mouth trouble sleeping constipation tir...
# 28845    nausea mouth trouble sleeping constipation tir...
#                                ...
# 35315    nausea mouth trouble sleeping constipation tir...
# 35316    nausea mouth trouble sleeping constipation tir...
# 35317    nausea mouth trouble sleeping constipation tir...
# 35318    nausea mouth trouble sleeping constipation tir...
# 35319    nausea mouth trouble sleeping constipation tir...
# Name: Sides, Length: 3347, dtype: object

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = stopwords.words('english')
df_new['Sides'] = df_new['Sides'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_new['Sides']
# Out:
# 28803    nausea mouth trouble sleeping constipation tir...
# 28817    nausea mouth trouble sleeping constipation tir...
# 28826    nausea mouth trouble sleeping constipation tir...
# 28834    nausea mouth trouble sleeping constipation tir...
# 28845    nausea mouth trouble sleeping constipation tir...
#                                ...
# 35315    nausea mouth trouble sleeping constipation tir...
# 35316    nausea mouth trouble sleeping constipation tir...
# 35317    nausea mouth trouble sleeping constipation tir...
# 35318    nausea mouth trouble sleeping constipation tir...
# 35319    nausea mouth trouble sleeping constipation tir...
# Name: Sides, Length: 3347, dtype: object

# %% [markdown]
# ###  Reviews

# %%
df_new.review= df_new.Reviews.apply(cleaning_text)
df_new.review
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18468\2463508707.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_new.review= df_new.Reviews.apply(cleaning_text)
# 28803    horrible brain zaps very graphic tragic dreams...
# 28817    helped depression anxiety having trouble sleeping
# 28826    nauseated almost immediately diareaha bedridde...
# 28834                           haven seen much difference
# 28845    started taking zoloft after diagnosed with dep...
#                                ...
# 35315    have been taking lexapro about weeks medicine ...
# 35316    took lexapro years never significant effects f...
# 35317    while using this medication feel much better f...
# 35318    this drug made feel like should have felt whol...
# 35319    this medication turned easy going into impulsi...
# Name: Reviews, Length: 3347, dtype: object

# %% [markdown]
# # Removing stopwords

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = stopwords.words('english')
df_new['Reviews'] = df_new['Reviews'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_new['Reviews']
# Out:
# 28803    I got horrible brain zaps graphic tragic dream...
# 28817    It helped depression anxiety. And I trouble sl...
# 28826    Was nauseated almost immediately. Diareaha bed...
# 28834                                seen much difference.
# 28845    I started taking Zoloft I diagnosed depression...
#                                ...
# 35315    I taking Lexapro 8 weeks. The medicine working...
# 35316    I took Lexapro years ago never significant eff...
# 35317    While I using medication I feel much better. I...
# 35318    This drug made feel like I felt whole life. I ...
# 35319    This medication turned easy going man impulsiv...
# Name: Reviews, Length: 3347, dtype: object

# %% [markdown]
# ### Condition

# %%
df_new.Condition=df_new.Condition.apply(cleaning_text)
df_new.Condition
# Out:
# 28803    anxiousness associated with depression
# 28817                                depression
# 28826                                depression
# 28834    anxiousness associated with depression
# 28845                                depression
#                           ...
# 35315                 repeated episodes anxiety
# 35316                        bipolar depression
# 35317                                     other
# 35318                                depression
# 35319                                     other
# Name: Condition, Length: 3347, dtype: object

# %% [markdown]
# ### Gender

# %%
df_new['Sex'].value_counts()
# Out:
# Female    2661
# Male       686
# Name: Sex, dtype: int64

# %% [markdown]
# # Handling age group

# %%
df_new['Age'].value_counts()
# Out:
# 25-34         729
# 45-54         722
# 35-44         706
# 55-64         497
# 19-24         352
# 65-74         155
# 13-18         140
# 75 or over     42
# 7-12            3
# 3-6             1
# Name: Age, dtype: int64

# %%
df_new['Age'].unique()
# Out:
# array(['35-44', '55-64', '65-74', '75 or over', '45-54', '13-18', '25-34',
#        '19-24', '7-12', '3-6'], dtype=object)

# %%
df_new['Age']=df_new['Age'].str.replace('75 or over','75-100')

# %%
df_new['Age'].value_counts()
# Out:
# 25-34     729
# 45-54     722
# 35-44     706
# 55-64     497
# 19-24     352
# 65-74     155
# 13-18     140
# 75-100     42
# 7-12        3
# 3-6         1
# Name: Age, dtype: int64

# %% [markdown]
# # Outliers detection

# %%
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.boxplot(df_new["EaseofUse"])
plt.title("Ease Of Use")

plt.subplot(2, 2, 2)
plt.boxplot(df_new["Effectiveness"])
plt.title("Effectiveness")

plt.subplot(2, 2, 3)
plt.boxplot(df_new["Satisfaction"])
plt.title("Satisfaction")

plt.subplot(2, 2, 4)
plt.boxplot(df_new["UsefulCount"])
plt.title("Useful Count")

plt.show()

# %% [markdown]
# #### Outliers are present in EaseofUse and UsefulCount columns.

# %% [markdown]
# # Removing outliers

# %%
def outliers(df, ft):
    Q1 = df[ft].quantile(0.25)
    Q3 = df[ft].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    ls = df.index[(df[ft] < lower) | (df[ft] > upper)]
    return ls

# %%
index_list = []
for feature in ['UsefulCount', 'EaseofUse']:
    index_list.extend(outliers(df_new, feature))
index_list
# Out:
# [28963,
#  28991,
#  29179,
#  29271,
#  29321,
#  29348,
#  29360,
#  29366,
#  29405,
#  29447,
#  29558,
#  29672,
#  29882,
#  29927,
#  30104,
#  30245,
#  30332,
#  30431,
#  30536,
#  30548,
#  30596,
#  30737,
#  30791,
#  30806,
#  30809,
#  30824,
#  30845,
#  30854,
#  30881,
#  30887,
#  30917,
#  30938,
#  30944,
#  30965,
#  30971,
#  30992,
#  31019,
#  31031,
#  31043,
#  31055,
#  31067,
#  31076,
#  31133,
#  31136,
#  31196,
#  31220,
#  31232,
#  31259,
#  31262,
#  31376,
#  31589,
#  31601,
#  31727,
#  31949,
#  31991,
#  32096,
#  32180,
#  32306,
#  32314,
#  32345,
#  32347,
#  32350,
#  32353,
#  32354,
#  32360,
#  32361,
#  32367,
#  32369,
#  32495,
#  32501,
#  32502,
#  32653,
#  32716,
#  32724,
#  32764,
#  32771,
#  32772,
#  32774,
#  32776,
#  32777,
#  32808,
#  32821,
#  32827,
#  32840,
#  32844,
#  32869,
#  32907,
#  32910,
#  32916,
#  32918,
#  32930,
#  32949,
#  32967,
#  33016,
#  33049,
#  33063,
#  33064,
#  33066,
#  33069,
#  33071,
# ...

# %%
#define a function called 'remove' which returns a cleaned data without outliers
def remove(df,ls):
    ls=sorted(set(ls)) #to sort and remove multiple copies(to get unique)
    df=df.drop(ls)
    return df

# %%
df_new.shape
# Out:
# (3347, 14)

# %%
df_new=remove(df_new,index_list)

# %%
df_new.shape
# Out:
# (2902, 14)

# %% [markdown]
# # UsefulCount and EasofUse columns post outliers removal

# %%
plt.boxplot(df_new["UsefulCount"])
plt.title('Box plot of Useful Count')
# Out:
# Text(0.5, 1.0, 'Box plot of Useful Count')

# %%
plt.boxplot(df_new["EaseofUse"])
plt.title('Box plot of Ease Of Use')
# Out:
# Text(0.5, 1.0, 'Box plot of Ease Of Use')

# %% [markdown]
# ### Satisfaction column

# %%
df_new['Satisfaction'].value_counts()
# Out:
# 5.0    1082
# 4.0     673
# 3.0     483
# 1.0     413
# 2.0     251
# Name: Satisfaction, dtype: int64

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ### Creation of a new SideEffects column

# %%
df1 = np.where(df_new['Satisfaction'] == 1.0, "Nil", df_new['Satisfaction'])
df1 = np.where(df_new['Satisfaction'] == 2.0, "Mild", df1)
df1 = np.where(df_new['Satisfaction'] == 3.0, "Moderate", df1)
df1 = np.where(df_new['Satisfaction'] == 4.0, "Severe", df1)
df1 = np.where(df_new['Satisfaction'] == 5.0, "Extreme", df1)

# %%
df_new['SideEffects']=df1

# %% [markdown]
# ## Since DrugId is the same, dropping the column

# %%
df_new.drop(['Satisfaction','DrugId'], inplace=True, axis=1)

# %%
df_new.head()
# Out:
#                  Name     Sex              Race     Age  \
# 28817    Jordan Baker    Male  African American   55-64
# 28826     Regina Leon  Female          American   65-74
# 28834   Lisa Mcmillan  Female             Asian  75-100
# 28845   Karen Higgins    Male  African American   35-44
# 28854  Matthew Austin  Female          Hispanic   45-54
#
#                                     Condition        Date     Drug  EaseofUse  \
# 28817                              depression   1/23/2020  lexapro        5.0
# 28826                              depression   1/21/2020  lexapro        3.0
# 28834  anxiousness associated with depression  12/27/2019  lexapro        4.0
# 28845                              depression  12/20/2019  lexapro        5.0
# 28854               repeated episodes anxiety   12/9/2019  lexapro        5.0
#
#        Effectiveness                                            Reviews  \
# 28817            3.0  It helped depression anxiety. And I trouble sl...
# ...

# %%
df_copy = df_new.copy()

# %% [markdown]
# # Feature reduction

# %% [markdown]
# ## Correlation analysis

# %% [markdown]
# ### Correlation matrix is plotted to check the relationship between variables

# %%
corrmatrix = df_new.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corrmatrix, vmin=-0.4, vmax=0.9, annot=True, cmap='BuPu', linewidth=0.2)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18468\4021107049.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmatrix = df_new.corr()
# <Axes: >

# %% [markdown]
# ### Here, being common, dropped the Drug, Sides columns. The other columns such as Date, Name, Reviews and UsefulCount are also dropped since these doesn't deal with side effects of the drug.

# %%
df_new = df_new.drop(columns=['Name', 'Drug', 'Date', 'Sides', 'Reviews', 'UsefulCount'], axis=1)
df_new = df_new.reset_index(drop=True)
df_new.head()
# Out:
#       Sex              Race     Age                               Condition  \
# 0    Male  African American   55-64                              depression
# 1  Female          American   65-74                              depression
# 2  Female             Asian  75-100  anxiousness associated with depression
# 3    Male  African American   35-44                              depression
# 4  Female          Hispanic   45-54               repeated episodes anxiety
#
#    EaseofUse  Effectiveness SideEffects
# 0        5.0            3.0    Moderate
# 1        3.0            1.0         Nil
# 2        4.0            2.0        Mild
# 3        5.0            5.0      Severe
# 4        5.0            5.0     Extreme

# %%
df_new.shape
# Out:
# (2902, 7)

# %% [markdown]
# # Encoding

# %%
#Finding categorical columns and chnaging datatype
for cl in df_new.select_dtypes(include='object'):
    df_new[cl] = df_new[cl].astype('category')
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2902 entries, 0 to 2901
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sex            2902 non-null   category
#  1   Race           2902 non-null   category
#  2   Age            2902 non-null   category
#  3   Condition      2902 non-null   category
#  4   EaseofUse      2902 non-null   float64
#  5   Effectiveness  2902 non-null   float64
#  6   SideEffects    2902 non-null   category
# dtypes: category(5), float64(2)
# memory usage: 60.9 KB

# %%
df_new.columns
# Out:
# Index(['Sex', 'Race', 'Age', 'Condition', 'EaseofUse', 'Effectiveness',
#        'SideEffects'],
#       dtype='object')

# %%
df_new.head()
# Out:
#       Sex              Race     Age                               Condition  \
# 0    Male  African American   55-64                              depression
# 1  Female          American   65-74                              depression
# 2  Female             Asian  75-100  anxiousness associated with depression
# 3    Male  African American   35-44                              depression
# 4  Female          Hispanic   45-54               repeated episodes anxiety
#
#    EaseofUse  Effectiveness SideEffects
# 0        5.0            3.0    Moderate
# 1        3.0            1.0         Nil
# 2        4.0            2.0        Mild
# 3        5.0            5.0      Severe
# 4        5.0            5.0     Extreme

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
for col in ['Race', 'Age', 'Sex', 'Condition', 'SideEffects']:
    df_new[col] = label.fit_transform(df_new[col].astype(str))

df_label = df_new

# %%
df_new.head()
# Out:
#    Sex  Race  Age  Condition  EaseofUse  Effectiveness  SideEffects
# 0    1     0    6          3        5.0            3.0            2
# 1    0     1    7          3        3.0            1.0            3
# 2    0     2    9          0        4.0            2.0            1
# 3    1     0    4          3        5.0            5.0            4
# 4    0     4    5          9        5.0            5.0            0

# %%
df_new.shape
# Out:
# (2902, 7)

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
scale = ['Effectiveness', 'EaseofUse']
df_new[scale] = ss.fit_transform(df_new[scale])

# %%
df_new.shape
# Out:
# (2902, 7)

# %%
df_model = df_new.copy()

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Conditions - Topamax

# %%
lexapro['Condition'].value_counts().nlargest(12).plot(kind='bar',figsize=(8,8))
plt.suptitle("lexapro Conditions")
plt.xlabel('Condition')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### lexapro is used in the treatment of 11 conditions. Maximum users consume the drug for depression.

# %% [markdown]
# # Users by Gender - lexapro

# %%
plt.figure(figsize = (4,4))
s=sns.countplot(x='Sex', data=df_copy)
plt.title('Users by Gender', fontsize=15)
plt.xlabel('Sex')
plt.ylabel('Count') 
plt.show()

# %% [markdown]
# ### Female count stands more than male count.

# %% [markdown]
# # Users by Race - lexapro

# %%
df_copy['Race'].value_counts().plot(kind='bar')
plt.title("Race", fontsize = 10)
plt.xlabel("Race", fontsize = 10)
plt.ylabel("Count", fontsize = 10)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### caucasians tops in this

# %% [markdown]
# # Users by Race and Gender

# %%
sns.countplot(x='Race',hue='Sex',data=df_copy)
plt.title("Users by Race and Gender", fontsize = 10)
# Out:
# Text(0.5, 1.0, 'Users by Race and Gender')

# %% [markdown]
# # Users by Age and Gender

# %%
order = ['o-2','3-6', '7-12', '13-18', '19-24', '25-34', '35-44', '45-54', '55-64', '65-74', '75-100']

# Plot the countplot with age groups in the custom order
plt.figure(figsize=(10, 6))
sns.countplot(x='Age', hue='Sex', data=df_copy, order=order)
plt.title("Users by Age and Gender", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Users by Age and Gender')

# %% [markdown]
# ### Females are the majority users. The usage have visible increase from 0-25 and it also decrease from 55-100. Most are from the age between 25 and 55.

# %% [markdown]
# # Correlation Heatmap

# %%
# heatmap of the data for checking the correlation
corrmatrix = df_copy.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corrmatrix,vmin=-0.4 , vmax=0.9, annot=True, cmap='YlGnBu' , linewidth=0.2)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18468\528421495.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmatrix = df_copy.corr()
# <Axes: >

# %% [markdown]
# ### No strong visible correlation between variables.

# %% [markdown]
# # Yearly Reviews - lexapro

# %%
df_copy['Date'] = pd.to_datetime(df_copy['Date'], errors = 'coerce')

#extracting year from Date
df_copy['Year'] = df_copy['Date'].dt.year

# %%
plt.figure(figsize=(10, 4))
sns.countplot(x='Year', data=df_copy, palette='colorblind')
plt.title('Number of Reviews per Year', fontsize=15)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %% [markdown]
# ### From this we can see that the reviews increases and its peaked at 2009 and decrease from there .

# %% [markdown]
# # Effectiveness

# %%
df_copy['Effectiveness'].value_counts().plot(kind='bar')
plt.title("Effectiveness", fontsize = 10)
plt.xlabel("Effectiveness", fontsize = 10)
plt.ylabel("Count", fontsize = 10)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Most users found lexapro as highly effective

# %% [markdown]
# # Ease of Use

# %%
df_copy['EaseofUse'].value_counts().plot(kind='bar')
plt.title("Ease of use", fontsize = 10)
plt.xlabel("EaseofUse", fontsize = 10)
plt.ylabel("Count", fontsize = 10)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Most people give lexapro good rating for its ease of use

# %% [markdown]
# # Useful Count

# %%
df_copy['UsefulCount'].value_counts().plot(kind='bar')
plt.title("Useful Count", fontsize = 15)
plt.xlabel("UsefulCount", fontsize = 15)
plt.ylabel("Count", fontsize = 15)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### As with usefulness of reviews, lexapro users throw a mixed bag with most not finding the reviews beneficial.

# %% [markdown]
# # Users by Effectiveness and Gender

# %%
plt.figure(figsize=(10,8))
g = sns.catplot(x="Effectiveness",col="Sex",
                data=df_copy, kind="count",
                height=6,aspect =.9);

# %% [markdown]
# ### lexapro is more effective on females

# %% [markdown]
# # Side Effects

# %%
plt.figure(figsize=(6,6))
df_copy['SideEffects'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# ### Extremely Severe Side Effects accounted for the most closely followed by No Side Effects. Mild symptoms accounted for the least.

# %% [markdown]
# # Side Effects and Age

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Age',hue='SideEffects',data=df_copy)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
order = ['3-6', '7-12', '13-18', '19-24', '25-34', '35-44', '45-54', '55-64', '65-74', '75-100']

plt.figure(figsize=(10, 6))
sns.countplot(x='Age', hue='SideEffects', data=df_copy, order=order)
plt.title('Number of Side Effects by Age Group', fontsize=15)
plt.xlabel('Age Group', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %% [markdown]
# ### age groups within 25-64 have the extreme side effects.

# %% [markdown]
# # Side Effects and Gender

# %%
plt.figure(figsize=(20,10))

g = sns.catplot(x="SideEffects",col="Sex",data=df_copy, kind="count",height=6,aspect =.9);

# %% [markdown]
# ### Side effects are more in females

# %% [markdown]
# # Side Effects and Race

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Race',hue='SideEffects',data=df_copy)
# Out:
# <Axes: xlabel='Race', ylabel='count'>

# %% [markdown]
# ### No evident difference in side effects on different race

# %% [markdown]
# # Splitting the data

# %%
#target
y = df_new['SideEffects']
X = df_new.drop(['SideEffects'],axis=1)

# %% [markdown]
# # Splitting the dataset into train and test sets

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, random_state=42,test_size=0.2)#assigninng values

# %% [markdown]
# # Modelling

# %% [markdown]
# ## 1. Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
logit_model = LogisticRegression(multi_class='multinomial')
logit_model.fit(X_train, y_train)
y_pred = logit_model.predict(X_test)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score,recall_score,f1_score,classification_report

# %% [markdown]
# ### Performance Evaluation

# %%
print("Accuracy is : ", accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy is :  67.12564543889845

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[193,   0,   2,   0,  18],
#        [  9,   0,  31,  16,   6],
#        [ 18,   0,  39,   6,  23],
#        [  6,   0,   8,  84,   7],
#        [ 28,   0,  13,   0,  74]], dtype=int64)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.5982838123782391
# Recall: 0.6712564543889845
# F1-score: 0.6319683009489991
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # 2. KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
acc_values = []
neighbors = np.arange(3,15)

# creating a loop to create KNN model for each K value
for k in neighbors:
#taking the instance of KNN to a variable.the variable name is classifier.
    classifier = KNeighborsClassifier(n_neighbors= k, metric = 'minkowski')    #no: of neighbors n the methode to measure the distance .instance is created
#we have to create the model.
    classifier = KNeighborsClassifier(n_neighbors= k)
    classifier.fit(X_train,y_train)
#have to predict output using this model.
    y_pred = classifier.predict(X_test)#KNN is created
#append the accurcy values to empty list in order to fing out maximum accuracy.
    acc = accuracy_score(y_test, y_pred)#taking accuracy values to variable acc 
#append these accuracy values to our list
    acc_values.append(acc)

# %%
acc_values
# Out:
# [0.5576592082616179,
#  0.5542168674698795,
#  0.5611015490533563,
#  0.5645438898450946,
#  0.5662650602409639,
#  0.576592082616179,
#  0.5800344234079173,
#  0.5834767641996558,
#  0.5903614457831325,
#  0.576592082616179,
#  0.5851979345955249,
#  0.5834767641996558]

# %% [markdown]
# ### To find which k value got the highest accuracy, plotted a graph between neighbor values (i.e. k values) and accuracy values

# %%
plt.plot(neighbors,acc_values,'o-')
plt.xlabel('k value')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %% [markdown]
# ## KNN model with k=11

# %%
classifier = KNeighborsClassifier(n_neighbors= 11, metric = 'minkowski')
classifier.fit(X_train,y_train)
y_pred = classifier.predict(X_test)

# %% [markdown]
# ## Performance Evaluation

# %%
print("Accuracy is : ", accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy is :  59.036144578313255

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[194,   1,   4,   0,  14],
#        [ 11,   5,  17,  12,  17],
#        [ 27,   9,  28,   2,  20],
#        [ 10,   8,  11,  71,   5],
#        [ 53,   1,  14,   2,  45]], dtype=int64)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.5550069921053076
# Recall: 0.5903614457831325
# F1-score: 0.5603567269575332

# %% [markdown]
# # 3. Support Vector Machine

# %% [markdown]
# ### a. Linear SVM

# %%
from sklearn.svm import SVC
svm_linear = SVC(kernel = 'linear')#creating an instance
svm_linear.fit(X_train,y_train)
y_pred = svm_linear.predict(X_test)

# %% [markdown]
# ## Performance Evaluation

# %%
print("Accuracy is : ", accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy is :  67.46987951807229

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[195,   0,   2,   0,  16],
#        [  9,   0,  31,  16,   6],
#        [ 19,   0,  39,   6,  22],
#        [  7,   0,   8,  84,   6],
#        [ 30,   0,  11,   0,  74]], dtype=int64)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.5997310194234401
# Recall: 0.6746987951807228
# F1-score: 0.6339712023883239
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### b. Polynomial SVM

# %%
svm_poly = SVC(kernel = 'poly', degree=3)
svm_poly.fit(X_train,y_train)
y_pred = svm_poly.predict(X_test)

# %% [markdown]
# ## Performance Evaluation

# %%
print("Accuracy is : ", accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy is :  63.339070567986234

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[197,   0,   0,   0,  16],
#        [ 11,   3,  26,   8,  14],
#        [ 28,   1,  32,   3,  22],
#        [  7,   0,  11,  77,  10],
#        [ 46,   0,  10,   0,  59]], dtype=int64)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.6445414713073349
# Recall: 0.6333907056798623
# F1-score: 0.5980234451263501

# %% [markdown]
# ### c. Radial SVM

# %%
svm_radial = SVC(kernel='rbf')
svm_radial.fit(X_train,y_train)
y_pred=svm_radial.predict(X_test)

# %% [markdown]
# ## Performance Evaluation

# %%
print("Accuracy is : ", accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy is :  67.12564543889845

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[195,   0,   2,   0,  16],
#        [  9,   0,  31,  15,   7],
#        [ 19,   0,  38,   6,  23],
#        [  7,   0,  11,  81,   6],
#        [ 30,   0,   9,   0,  76]], dtype=int64)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.5978066968214534
# Recall: 0.6712564543889845
# F1-score: 0.6310814143568501
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # 4.Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train,y_train)
y_pred = dt_model.predict(X_test)

# %% [markdown]
# ## Performance Evaluation

# %%
print("Accuracy is : ", accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy is :  58.519793459552496

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[185,   3,   6,   0,  19],
#        [  9,  13,  17,  17,   6],
#        [ 16,  15,  30,   6,  19],
#        [ 10,  20,  11,  60,   4],
#        [ 36,   7,  18,   2,  52]], dtype=int64)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.5734998187041442
# Recall: 0.5851979345955249
# F1-score: 0.5750941394646546

# %% [markdown]
# # 5. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
#training the model
rf.fit(X_train,y_train)
#to make predictions
y_pred=rf.predict(X_test)

# %% [markdown]
# ## Performance Evaluation

# %%
print("Accuracy is : ", accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy is :  63.85542168674698

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[187,   2,   7,   0,  17],
#        [ 12,   9,  24,  13,   4],
#        [ 16,   8,  34,   6,  22],
#        [ 10,   7,  10,  75,   3],
#        [ 33,   3,  12,   1,  66]], dtype=int64)

# %%
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.6160015312010991
# Recall: 0.6385542168674698
# F1-score: 0.6210382256964673

# %% [markdown]
# # Feature Importance

# %%
# Feature Importance
from sklearn.ensemble import RandomForestClassifier


rf = RandomForestClassifier()
rf.fit(X_train, y_train)

# Get feature importances
importances = rf.feature_importances_


importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)


print(importance_df)
# Out:
#          Feature  Importance
# 5  Effectiveness    0.435000
# 2            Age    0.156347
# 3      Condition    0.151160
# 1           Race    0.141526
# 4      EaseofUse    0.085015
# 0            Sex    0.030951

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# Define the hyperparameter grid to search
param_grid = {
    'C': [0.1, 1, 10, 100],       # Regularization parameter
    'kernel': ['linear', 'rbf']   # Kernel type
}

# Create the SVM model
svm_model = SVC()

# Create GridSearchCV with the SVM model and hyperparameter grid
grid_search = GridSearchCV(svm_model, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# Fit the GridSearchCV to the training data
grid_search.fit(X_train, y_train)

# Get the best hyperparameters and the corresponding best model
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

# Evaluate the best model on the test data
y_pred = best_model.predict(X_test)

# Calculate performance metrics for the best model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Best hyperparameters:", best_params)
print("Best model accuracy:", accuracy)
print("Best model precision:", precision)
print("Best model recall:", recall)
print("Best model F1-score:", f1)
# Out:
# Best hyperparameters: {'C': 1, 'kernel': 'linear'}
# Best model accuracy: 0.6746987951807228
# Best model precision: 0.5997310194234401
# Best model recall: 0.6746987951807228
# Best model F1-score: 0.6339712023883239
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # 6. Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier()
gb.fit(X_train,y_train)
y_pred = gb.predict(X_test)

# %% [markdown]
# ## Performance Evaluation

# %%
print('Accuracy is: ',accuracy_score(y_test,y_pred)*100)
# Out:
# Accuracy is:  66.60929432013769

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[190,   1,   1,   0,  21],
#        [  9,  12,  29,   6,   6],
#        [ 18,   5,  38,   2,  23],
#        [  7,  12,   7,  73,   6],
#        [ 28,   0,  12,   1,  74]], dtype=int64)

# %% [markdown]
# # 7. Extreme Gradient Boosting

# %%
from xgboost import XGBClassifier
#creating an instance
xgb=XGBClassifier()
xgb.fit(X_train,y_train)
y_pred= xgb.predict(X_test)

# %% [markdown]
# ## Performance Evaluation

# %%
print('Accuracy is: ',accuracy_score(y_test,y_pred)*100)
# Out:
# Accuracy is:  64.19965576592082

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[185,   2,   2,   0,  24],
#        [  9,  14,  23,   8,   8],
#        [ 17,   9,  31,   3,  26],
#        [  8,  12,   7,  71,   7],
#        [ 29,   1,  12,   1,  72]], dtype=int64)

# %% [markdown]
# # Inference

# %% [markdown]
# ### Accuracies of different models

# %% [markdown]
# 1.Logistic Regression Model: 67.13
#
# 2.KNN Model (k=11): 59.04
#
# 3.Support Vector Machine:
#
# 4.Linear SVM: 67.47
#
# 5.Polynomial SVM: 63.34
#
# 6.Radial SVM: 67.13
#
# 7.Decision Tree Classifier: 58.52
#
# 8.Random Forest: 63.86
#
# 9.Gradient Boosting: 66.61
#
# 10.Extreme Gradient Boosting: 64.20

# %% [markdown]
# ### Linear SVM model achieved the highest accuracy of 67.47%,
